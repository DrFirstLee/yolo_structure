# %%
import pandas as pd
import numpy as np

# %%
file_name ="korea_long_20250202-212521.csv"
df_raw =pd.read_csv(f"/app/yolo_structure/results/{file_name}")
# df_raw["datetime"] = pd.to_datetime(df_raw["datetime"], format="%Y%m%d-%H%M%S.%f")
df_raw .tail(5)
# Out:
#              datetime  distance    event detected     source_name  \
# 6211  20250202-212610         0     STOP      car  korea_long.mp4
# 6212  20250202-212610         0  REVERSE      car  korea_long.mp4
# 6213  20250202-212610         0     STOP      car  korea_long.mp4
# 6214  20250202-212610         0     STOP      bus  korea_long.mp4
# 6215  20250202-212610         0     STOP      bus  korea_long.mp4
#
#                 frame_hash  frame_num
# 6211     korea_long_STOP_1       1707
# 6212  korea_long_REVERSE_3       1707
# 6213     korea_long_STOP_4       1707
# 6214     korea_long_STOP_5       1707
# 6215     korea_long_STOP_6       1707

# %%
# frame_hash별로 그룹핑하고, 1초 이내 5개 이상 존재하는 경우 찾기
df_raw_person = df_raw[df_raw["detected"] == "person"]
df_raw_person

# frame_hash별로 그룹화 후 frame_num 연속성 확인
df_filtered_person = pd.DataFrame()

grouped = df_raw_person.groupby("frame_hash")
for _, group in grouped:
    group = group.sort_values(by="frame_num").reset_index(drop=True)
    group["diff"] = group["frame_num"].diff().fillna(1)
    group["consec_group"] = (group["diff"] != 1).cumsum()
    valid_groups = group.groupby("consec_group").filter(lambda x: len(x) >= 5)
    df_filtered_person = pd.concat([df_filtered_person, valid_groups.drop(columns=["diff", "consec_group"])])

# 결과 출력
df_filtered_person
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# frame_hash별로 그룹핑하고, 1초 이내 5개 이상 존재하는 경우 찾기
df_raw_stop = df_raw[df_raw["event"] == "STOP"]
df_raw_stop

# frame_hash별로 그룹화 후 frame_num 연속성 확인
df_filtered_stop = pd.DataFrame()

grouped = df_raw_stop.groupby("frame_hash")
for _, group in grouped:
    group = group.sort_values(by="frame_num").reset_index(drop=True)
    group["diff"] = group["frame_num"].diff().fillna(1)
    group["consec_group"] = (group["diff"] != 1).cumsum()
    valid_groups = group.groupby("consec_group").filter(lambda x: len(x) >= 5)
    df_filtered_stop = pd.concat([df_filtered_stop, valid_groups.drop(columns=["diff", "consec_group"])])

# 결과 출력
df_filtered_stop
# Out:
#            datetime  distance event detected     source_name  \
# 0   20250202-212522         0  STOP      bus  korea_long.mp4
# 1   20250202-212522         0  STOP      bus  korea_long.mp4
# 2   20250202-212522         0  STOP      bus  korea_long.mp4
# 3   20250202-212524         0  STOP      bus  korea_long.mp4
# 4   20250202-212527         0  STOP      bus  korea_long.mp4
# ..              ...       ...   ...      ...             ...
# 22  20250202-212559         0  STOP      bus  korea_long.mp4
# 23  20250202-212559         0  STOP      bus  korea_long.mp4
# 24  20250202-212559         0  STOP      bus  korea_long.mp4
# 25  20250202-212559         0  STOP      bus  korea_long.mp4
# 26  20250202-212559         0  STOP      bus  korea_long.mp4
#
#            frame_hash  frame_num
# 0   korea_long_STOP_1          2
# 1   korea_long_STOP_1          3
# 2   korea_long_STOP_1          4
# 3   korea_long_STOP_1          5
# 4   korea_long_STOP_1          6
# ..                ...        ...
# 22  korea_long_STOP_6        942
# 23  korea_long_STOP_6        943
# 24  korea_long_STOP_6        944
# 25  korea_long_STOP_6        945
# 26  korea_long_STOP_6        946
#
# [4691 rows x 7 columns]

# %%
# frame_hash별로 그룹핑하고, 1초 이내 5개 이상 존재하는 경우 찾기
df_raw_reverse = df_raw[df_raw["event"] == "REVERSE"]
df_raw_reverse

# frame_hash별로 그룹화 후 frame_num 연속성 확인
df_filtered_reverse = pd.DataFrame()

grouped = df_raw_reverse.groupby("frame_hash")
for _, group in grouped:
    group = group.sort_values(by="frame_num").reset_index(drop=True)
    group["diff"] = group["frame_num"].diff().fillna(1)
    group["consec_group"] = (group["diff"] != 1).cumsum()
    valid_groups = group.groupby("consec_group").filter(lambda x: len(x) >= 3)
    df_filtered_reverse = pd.concat([df_filtered_reverse, valid_groups.drop(columns=["diff", "consec_group"])])

# 결과 출력
df_filtered_reverse
# Out:
#            datetime  distance    event detected     source_name  \
# 44  20250202-212610         0  REVERSE      car  korea_long.mp4
# 45  20250202-212610         0  REVERSE      car  korea_long.mp4
# 46  20250202-212610         0  REVERSE      car  korea_long.mp4
# 47  20250202-212610         0  REVERSE      car  korea_long.mp4
# 48  20250202-212610         0  REVERSE      car  korea_long.mp4
# 49  20250202-212610         0  REVERSE      car  korea_long.mp4
# 61  20250202-212609         0  REVERSE      car  korea_long.mp4
# 62  20250202-212609         0  REVERSE      car  korea_long.mp4
# 63  20250202-212609         0  REVERSE      car  korea_long.mp4
# 29  20250202-212609         0  REVERSE      bus  korea_long.mp4
# 30  20250202-212609         0  REVERSE      car  korea_long.mp4
# 31  20250202-212609         0  REVERSE      car  korea_long.mp4
#
#               frame_hash  frame_num
# 44  korea_long_REVERSE_3       1690
# 45  korea_long_REVERSE_3       1691
# 46  korea_long_REVERSE_3       1692
# 47  korea_long_REVERSE_3       1696
# 48  korea_long_REVERSE_3       1697
# 49  korea_long_REVERSE_3       1698
# 61  korea_long_REVERSE_5       1676
# 62  korea_long_REVERSE_5       1677
# 63  korea_long_REVERSE_5       1678
# 29  korea_long_REVERSE_6       1679
# 30  korea_long_REVERSE_6       1680
# 31  korea_long_REVERSE_6       1681

# %%
import ollama
import os
import cv2

origin_dir = "/app"
## 최종 저장경로 설정!!
results_dir = os.path.join(origin_dir,"yolo_structure","results")
## 사건파일저장
crop_save_dir = os.path.join(results_dir,"frame_img")

# %%
llm_res_l = []
for index,value in df_filtered_stop.iterrows():
    if value["detected"] !="car":
        llm_res_l.append(value["detected"])
        continue
   
    crop_filename = os.path.join(crop_save_dir,value["frame_hash"]+"_"+ str(value["frame_num"]) +".jpg")
    res = ollama.chat(
        model= "llama3.2-vision:11b",
        messages=[
            {
                'role': 'user',
                'content': "tell me what is in this image. Answer only one in [SEDAN/SUV/VAN/TRUCK/BUS] answer in one word",
                'images': [crop_filename]
            }
        ]
    )
    
    print(res['message']['content'])

    final_result = res['message']['content'].upper().replace(".","").replace(" ","")
    print(f"{crop_filename} / Ollama Result: {final_result}")
    llm_res_l.append(final_result)
df_filtered_stop["llm_res"] = llm_res_l
df_filtered_stop
# Out:
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_1_1482.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_1_1483.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_1_1484.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_1_1485.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_1_1486.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_14.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_15.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_16.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_17.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_18.jpg / Ollama Result: SEDAN
# sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_19.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_20.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_21.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_22.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_23.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_24.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_25.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_26.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_27.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_28.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_29.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_30.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_31.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_32.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_33.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_34.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_35.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_36.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_37.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_38.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_39.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_40.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_41.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_42.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_43.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_44.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_45.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_46.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_47.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_48.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_49.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_50.jpg / Ollama Result: SEDAN
# sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_51.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_52.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_53.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_54.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_55.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_56.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_57.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_58.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_78.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_79.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_80.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_81.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_82.jpg / Ollama Result: SEDAN
# sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_83.jpg / Ollama Result: SEDAN
# sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_84.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_85.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_86.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_87.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_88.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_89.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_90.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_91.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_93.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_94.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_95.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_96.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_97.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_98.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_99.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_100.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_101.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_102.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_103.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_104.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_105.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_106.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_107.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_108.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_109.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_110.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_111.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_112.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_113.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_114.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_115.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_116.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_117.jpg / Ollama Result: SEDAN
# sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_119.jpg / Ollama Result: SEDAN
# sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_120.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_121.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_122.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_123.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_124.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_125.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_126.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_144.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_145.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_146.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_147.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_148.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_149.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_150.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_151.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_152.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_153.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_154.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_155.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_190.jpg / Ollama Result: SEDAN
# sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_191.jpg / Ollama Result: SEDAN
# sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_192.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_193.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_194.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_195.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_196.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_197.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_198.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_200.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_201.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_202.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_203.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_204.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_205.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_206.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_207.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_208.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_209.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_210.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_211.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_212.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_213.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_214.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_215.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_216.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_217.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_218.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_219.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_220.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_221.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_222.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_223.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_224.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_225.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_226.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_227.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_228.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_229.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_230.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_231.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_232.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_233.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_234.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_235.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_236.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_237.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_238.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_239.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_240.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_241.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_242.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_243.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_244.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_245.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_246.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_247.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_248.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_258.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_259.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_260.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_261.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_262.jpg / Ollama Result: SEDAN
# Sedan.
# /app/yolo_structure/results/frame_img/korea_long_STOP_2_263.jpg / Ollama Result: SEDAN
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 8
#       5     continue
#       7 crop_filename = os.path.join(crop_save_dir,value["frame_hash"]+"_"+ str(value["frame_num"]) +".jpg")
# ----> 8 res = ollama.chat(
#       9     model= "llama3.2-vision:11b",
#      10     messages=[
#      11         {
#      12             'role': 'user',
#      13             'content': "tell me what is in this image. Answer only one in [SEDAN/SUV/VAN/TRUCK/BUS] answer in one word",
#      14             'images': [crop_filename]
#      15         }
#      16     ]
#      17 )
#      19 print(res['message']['content'])
#      21 final_result = res['message']['content'].upper().replace(".","").replace(" ","")
#
# File /opt/conda/lib/python3.12/site-packages/ollama/_client.py:333, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     289 def chat(
#     290   self,
#     291   model: str = '',
#    (...)
#     298   keep_alive: Optional[Union[float, str]] = None,
#     299 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     300   """
#     301   Create a chat response using the requested model.
#     302
#    (...)
#     331   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     332   """
# --> 333   return self._request(
#     334     ChatResponse,
#     335     'POST',
#     336     '/api/chat',
#     337     json=ChatRequest(
#     338       model=model,
#     339       messages=[message for message in _copy_messages(messages)],
#     340       tools=[tool for tool in _copy_tools(tools)],
#     341       stream=stream,
#     342       format=format,
#     343       options=options,
#     344       keep_alive=keep_alive,
#     345     ).model_dump(exclude_none=True),
#     346     stream=stream,
#     347   )
#
# File /opt/conda/lib/python3.12/site-packages/ollama/_client.py:178, in Client._request(self, cls, stream, *args, **kwargs)
#     174         yield cls(**part)
#     176   return inner()
# --> 178 return cls(**self._request_raw(*args, **kwargs).json())
#
# File /opt/conda/lib/python3.12/site-packages/ollama/_client.py:118, in Client._request_raw(self, *args, **kwargs)
#     116 def _request_raw(self, *args, **kwargs):
#     117   try:
# --> 118     r = self._client.request(*args, **kwargs)
#     119     r.raise_for_status()
#     120     return r
#
# File /opt/conda/lib/python3.12/site-packages/httpx/_client.py:827, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812     warnings.warn(message, DeprecationWarning)
#     814 request = self.build_request(
#     815     method=method,
#     816     url=url,
#    (...)
#     825     extensions=extensions,
#     826 )
# --> 827 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File /opt/conda/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /opt/conda/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /opt/conda/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /opt/conda/lib/python3.12/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File /opt/conda/lib/python3.12/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File /opt/conda/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File /opt/conda/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File /opt/conda/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File /opt/conda/lib/python3.12/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File /opt/conda/lib/python3.12/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File /opt/conda/lib/python3.12/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File /opt/conda/lib/python3.12/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/conda/lib/python3.12/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
llm_res_l = []
for index,value in df_filtered_reverse.iterrows():
    if value["detected"] !="car":
        llm_res_l.append(value["detected"])
        continue
   
    crop_filename = os.path.join(crop_save_dir,value["frame_hash"]+"_"+ str(value["frame_num"]) +".jpg")
    res = ollama.chat(
        model= "llama3.2-vision:11b",
        messages=[
            {
                'role': 'user',
                'content': "tell me what is in this image. Answer only one in [SEDAN/SUV/VAN/TRUCK/BUS] answer in one word",
                'images': [crop_filename]
            }
        ]
    )
    
    print(res['message']['content'])

    final_result = res['message']['content'].upper().replace(".","").replace(" ","")
    print(f"{crop_filename} / Ollama Result: {final_result}")
    llm_res_l.append(final_result)
df_filtered_reverse["llm_res"] = llm_res_l
df_filtered_reverse
